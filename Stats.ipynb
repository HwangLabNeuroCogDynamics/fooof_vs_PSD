# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns

# %%
fooof_df = pd.read_csv('Data/all_sub_results.csv')

# %%
psd_df = pd.read_csv('Data/theta_beta_all.csv')

# %%
fooof_df.head()
# Out:
#          sub  age sex  PO_EC_slope  PO_EC_yint  PO_EO_slope  PO_EO_yint  \
# 0  A00055486   16   F     0.916847  -12.026024     0.708279  -12.296212
# 1  A00063117   24   F     1.102935  -12.060568     1.116283  -12.235946
# 2  A00054836    8   F     1.599255  -10.478007     1.377756  -10.831005
# 3  A00054359   13   F     1.610714  -10.333942     1.416745  -10.950073
# 4  A00054517   10   M     0.522436   -9.317329     0.897068  -10.409788
#
#    MF_EC_slope  MF_EC_yint  MF_EO_slope     ...      PO_EO_BW_1  PO_EO_Peak_2  \
# 0     0.732309  -12.052227     0.511506     ...             NaN           NaN
# 1     1.025043  -11.998508     0.573955     ...             NaN           NaN
# 2     1.831959  -10.159336     1.516278     ...        4.771545     32.732274
# 3     1.660567  -10.281690     1.667737     ...        5.960934           NaN
# 4     0.469592   -9.398474     0.861099     ...        2.041841           NaN
#
# ...

# %%
psd_df.head()
# Out:
#    Unnamed: 0        sub  age sex  THETA_psds_EC_mf0  THETA_psds_EC_po0  \
# 0           0  A00055486   16   F       1.922216e-13       1.485649e-13
# 1           1  A00063117   24   F       1.360168e-13       1.082372e-13
# 2           2  A00054836    8   F       2.548348e-12       5.217749e-12
# 3           3  A00054359   13   F       1.260574e-11       2.271412e-11
# 4           4  A00054517   10   M       3.215473e-10       3.441009e-10
#
#    THETA_psds_EO_mf0  THETA_psds_EO_po0  BETA_psds_EC_mf0  BETA_psds_EC_po0  \
# 0       2.304684e-13       1.115890e-13      1.114251e-13      7.406117e-14
# 1       4.620798e-14       6.219977e-14      4.684825e-14      5.432760e-14
# 2       1.609531e-12       1.847671e-12      3.566276e-13      5.225668e-13
# 3       3.130827e-12       2.860281e-12      8.199535e-13      1.395559e-12
# 4       8.513071e-12       7.988080e-12      9.647041e-11      1.006440e-10
#
# ...

# %% [markdown]
# # Fooof

# %%
# build regressors
X = sm.add_constant(fooof_df['age'])
print X
# Out:
#     const  age
# 0     1.0   16
# 1     1.0   24
# 2     1.0    8
# 3     1.0   13
# 4     1.0   10
# 5     1.0   10
# 6     1.0    9
# 7     1.0   24
# 8     1.0   22
# 9     1.0   12
# 10    1.0   12
# 11    1.0   15
# 12    1.0   14
# 13    1.0   13
# 14    1.0   17
# 15    1.0   15
# 16    1.0   12
# 17    1.0    9
# 18    1.0   12
# 19    1.0    9
# 20    1.0   13
# 21    1.0   18
# 22    1.0   14
# 23    1.0   12
# 24    1.0   13
# 25    1.0   11
# 26    1.0   16
# 27    1.0   13
# 28    1.0   10
# 29    1.0   18
# 30    1.0   10
# 31    1.0   22
# 32    1.0   10
# 33    1.0   23
# 34    1.0   18
# 35    1.0   10
# 36    1.0   14
# 37    1.0   15
# 38    1.0   11
# 39    1.0    9

# %%
# which column should we use
for columns in fooof_df.iloc[:,3:]:
    print columns
    
D_Vars = ['PO_EC_slope', 'PO_EC_yint', 'PO_EO_slope', 'PO_EO_yint', 'MF_EC_slope', 'MF_EC_yint', 'MF_EO_slope', 'MF_EO_yint']
# Out:
# PO_EC_slope
# PO_EC_yint
# PO_EO_slope
# PO_EO_yint
# MF_EC_slope
# MF_EC_yint
# MF_EO_slope
# MF_EO_yint
# PO_EC_alphaPeak
# PO_EC_alphaBW
# PO_EC_alphaAMP
# PO_EO_alphaPeak
# PO_EO_alphaBW
# PO_EO_alphaAMP
# PO_EC_betaPeak
# PO_EC_betaBW
# PO_EC_betaAMP
# PO_EO_betaPeak
# PO_EO_betaBW
# PO_EO_betaAMP
# PO_EC_thetaPeak
# PO_EC_thetaBW
# PO_EC_thetaAMP
# PO_EO_thetaPeak
# PO_EO_thetaBW
# PO_EO_thetaAMP
# MF_EC_alphaPeak
# MF_EC_alphaBW
# MF_EC_alphaAMP
# MF_EO_alphaPeak
# MF_EO_alphaBW
# MF_EO_alphaAMP
# MF_EC_betaPeak
# MF_EC_betaBW
# MF_EC_betaAMP
# MF_EO_betaPeak
# MF_EO_betaBW
# MF_EO_betaAMP
# MF_EC_thetaPeak
# MF_EC_thetaBW
# MF_EC_thetaAMP
# MF_EO_thetaPeak
# MF_EO_thetaBW
# MF_EO_thetaAMP
# PO_EC_Peak_1
# PO_EC_AMP_1
# PO_EC_BW_1
# MF_EC_Peak_1
# MF_EC_AMP_1
# MF_EC_BW_1
# MF_EO_Peak_1
# MF_EO_AMP_1
# MF_EO_BW_1
# PO_EC_Peak_2
# PO_EC_AMP_2
# PO_EC_BW_2
# PO_EO_Peak_1
# PO_EO_AMP_1
# PO_EO_BW_1
# PO_EO_Peak_2
# PO_EO_AMP_2
# PO_EO_BW_2
# MF_EC_Peak_2
# MF_EC_AMP_2
# ...

# %%
fooof_df['EC_slope_sum'] = fooof_df['PO_EC_slope'] + fooof_df['MF_EC_slope']

# %%
fooof_df['EC_yint_sum'] = fooof_df['PO_EC_yint'] + fooof_df['MF_EC_yint']

# %%
sm.OLS(fooof_df['EC_yint_sum'], X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            EC_yint_sum   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     23.94
# Date:                Wed, 24 Jul 2019   Prob (F-statistic):           1.86e-05
# Time:                        10:22:44   Log-Likelihood:                -67.372
# No. Observations:                  40   AIC:                             138.7
# Df Residuals:                      38   BIC:                             142.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -18.0073      0.710    -25.345      0.000     -19.446     -16.569
# ...

# %%
sm.OLS(fooof_df['EC_slope_sum'], X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           EC_slope_sum   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     8.177
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):            0.00685
# Time:                        10:52:04   Log-Likelihood:                -37.459
# No. Observations:                  40   AIC:                             78.92
# Df Residuals:                      38   BIC:                             82.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6649      0.336     10.896      0.000       2.984       4.346
# ...

# %%
sns.lmplot(x='age', y='EC_slope_sum', data=fooof_df,
           palette="muted", height=4)
# Out:
# /Users/kaihwang/anaconda2/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Theta/beta PSD

# %%
for columns in psd_df.iloc[:,4:]:
    print columns
# Out:
# THETA_psds_EC_mf0
# THETA_psds_EC_po0
# THETA_psds_EO_mf0
# THETA_psds_EO_po0
# BETA_psds_EC_mf0
# BETA_psds_EC_po0
# BETA_psds_EO_mf0
# BETA_psds_EO_po0
# BETA_psds_EC_mf1
# BETA_psds_EC_po1
# BETA_psds_EO_mf1
# BETA_psds_EO_po1
# BETA_psds_EC_mf2
# BETA_psds_EC_po2
# BETA_psds_EO_mf2
# BETA_psds_EO_po2
# BETA_psds_EC_mf3
# BETA_psds_EC_po3
# BETA_psds_EO_mf3
# BETA_psds_EO_po3
# betas_avg_EC_mf
# betas_avg_EC_po
# betas_avg_EO_mf
# betas_avg_EO_po
# THETA_OVER_BETA_EC_mf
# THETA_OVER_BETA_EO_mf
# THETA_OVER_BETA_EC_po
# THETA_OVER_BETA_EO_po

# %%
X = sm.add_constant(psd_df['age'])
print X
# Out:
#     const  age
# 0     1.0   16
# 1     1.0   24
# 2     1.0    8
# 3     1.0   13
# 4     1.0   10
# 5     1.0   10
# 6     1.0    9
# 7     1.0   24
# 8     1.0   22
# 9     1.0   12
# 10    1.0   12
# 11    1.0   15
# 12    1.0   14
# 13    1.0   13
# 14    1.0   17
# 15    1.0   15
# 16    1.0   12
# 17    1.0    9
# 18    1.0   12
# 19    1.0    9
# 20    1.0   13
# 21    1.0   18
# 22    1.0   14
# 23    1.0   12
# 24    1.0   13
# 25    1.0   11
# 26    1.0   16
# 27    1.0   13
# 28    1.0   10
# 29    1.0   18
# 30    1.0   10
# 31    1.0   22
# 32    1.0   10
# 33    1.0   23
# 34    1.0   18
# 35    1.0   10
# 36    1.0   14
# 37    1.0   15
# 38    1.0   11
# 39    1.0    9

# %%
psd_df['theta_beta_sum'] = psd_df['THETA_OVER_BETA_EC_mf'] + psd_df['THETA_OVER_BETA_EC_po']

# %%
sm.OLS(psd_df['theta_beta_sum'], X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         theta_beta_sum   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     3.426
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):             0.0720
# Time:                        10:56:23   Log-Likelihood:                -160.00
# No. Observations:                  40   AIC:                             324.0
# Df Residuals:                      38   BIC:                             327.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.4806      7.199      4.651      0.000      18.908      48.054
# ...

# %%
sns.lmplot(x='age', y='theta_beta_sum', data=psd_df,
           palette="muted", height=4)

# %%
df = pd.merge(psd_df, fooof_df, on='sub')

# %%
df.head()
# Out:
#    Unnamed: 0        sub  age_x sex_x  THETA_psds_EC_mf0  THETA_psds_EC_po0  \
# 0           0  A00055486     16     F       1.922216e-13       1.485649e-13
# 1           1  A00063117     24     F       1.360168e-13       1.082372e-13
# 2           2  A00054836      8     F       2.548348e-12       5.217749e-12
# 3           3  A00054359     13     F       1.260574e-11       2.271412e-11
# 4           4  A00054517     10     M       3.215473e-10       3.441009e-10
#
#    THETA_psds_EO_mf0  THETA_psds_EO_po0  BETA_psds_EC_mf0  BETA_psds_EC_po0  \
# 0       2.304684e-13       1.115890e-13      1.114251e-13      7.406117e-14
# 1       4.620798e-14       6.219977e-14      4.684825e-14      5.432760e-14
# 2       1.609531e-12       1.847671e-12      3.566276e-13      5.225668e-13
# 3       3.130827e-12       2.860281e-12      8.199535e-13      1.395559e-12
# 4       8.513071e-12       7.988080e-12      9.647041e-11      1.006440e-10
#
# ...

# %%
import statsmodels.formula.api as smf

# %%
smf.ols(formula = "age_x ~ 1 + theta_beta_sum + EC_slope_sum", data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  age_x   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     3.982
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):             0.0271
# Time:                        11:03:28   Log-Likelihood:                -111.53
# No. Observations:                  40   AIC:                             229.1
# Df Residuals:                      37   BIC:                             234.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # PSD

# %%
df = pd.read_csv('Data/psd_all_sub_results.csv')

# %%
df.head()
# Out:
#          sub  age sex   psds_EC_mf0   psds_EC_po0   psds_EO_mf0   psds_EO_po0  \
# 0  A00055486   16   F  3.597035e-13  2.726861e-13  3.868299e-13  2.184946e-13
# 1  A00063117   24   F  2.912688e-13  1.910850e-13  8.654527e-14  1.171513e-13
# 2  A00054836    8   F  3.901435e-12  3.486652e-12  2.620731e-12  2.271580e-12
# 3  A00054359   13   F  4.326054e-12  4.411265e-12  2.965599e-12  1.657344e-12
# 4  A00054517   10   M  5.239014e-10  5.291605e-10  1.260016e-11  1.228743e-11
#
#     psds_EC_mf1   psds_EC_po1   psds_EO_mf1      ...        psds_EO_mf9  \
# 0  1.922216e-13  1.485649e-13  2.304684e-13      ...       1.035131e-13
# 1  1.360168e-13  1.082372e-13  4.620798e-14      ...       1.719140e-14
# 2  2.548348e-12  5.217749e-12  1.609531e-12      ...       9.434853e-14
# 3  1.260574e-11  2.271412e-11  3.130827e-12      ...       1.012759e-13
# 4  3.215473e-10  3.441009e-10  8.513071e-12      ...       1.336656e-12
#
# ...

# %%
df.columns[3:]
# Out:
# Index([u'psds_EC_mf0', u'psds_EC_po0', u'psds_EO_mf0', u'psds_EO_po0',
#        u'psds_EC_mf1', u'psds_EC_po1', u'psds_EO_mf1', u'psds_EO_po1',
#        u'psds_EC_mf2', u'psds_EC_po2', u'psds_EO_mf2', u'psds_EO_po2',
#        u'psds_EC_mf3', u'psds_EC_po3', u'psds_EO_mf3', u'psds_EO_po3',
#        u'psds_EC_mf4', u'psds_EC_po4', u'psds_EO_mf4', u'psds_EO_po4',
#        u'psds_EC_mf5', u'psds_EC_po5', u'psds_EO_mf5', u'psds_EO_po5',
#        u'psds_EC_mf6', u'psds_EC_po6', u'psds_EO_mf6', u'psds_EO_po6',
#        u'psds_EC_mf7', u'psds_EC_po7', u'psds_EO_mf7', u'psds_EO_po7',
#        u'psds_EC_mf8', u'psds_EC_po8', u'psds_EO_mf8', u'psds_EO_po8',
#        u'psds_EC_mf9', u'psds_EC_po9', u'psds_EO_mf9', u'psds_EO_po9',
#        u'psds_EC_mf10', u'psds_EC_po10', u'psds_EO_mf10', u'psds_EO_po10',
#        u'psds_EC_mf11', u'psds_EC_po11', u'psds_EO_mf11', u'psds_EO_po11'],
#       dtype='object')

# %%
X = sm.add_constant(psd_df['age'])
print X
# Out:
#     const  age
# 0     1.0   16
# 1     1.0   24
# 2     1.0    8
# 3     1.0   13
# 4     1.0   10
# 5     1.0   10
# 6     1.0    9
# 7     1.0   24
# 8     1.0   22
# 9     1.0   12
# 10    1.0   12
# 11    1.0   15
# 12    1.0   14
# 13    1.0   13
# 14    1.0   17
# 15    1.0   15
# 16    1.0   12
# 17    1.0    9
# 18    1.0   12
# 19    1.0    9
# 20    1.0   13
# 21    1.0   18
# 22    1.0   14
# 23    1.0   12
# 24    1.0   13
# 25    1.0   11
# 26    1.0   16
# 27    1.0   13
# 28    1.0   10
# 29    1.0   18
# 30    1.0   10
# 31    1.0   22
# 32    1.0   10
# 33    1.0   23
# 34    1.0   18
# 35    1.0   10
# 36    1.0   14
# 37    1.0   15
# 38    1.0   11
# 39    1.0    9

# %%
for columns in df.iloc[:,3:]:
    
    model = sm.OLS(df[columns], X).fit()
    print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            psds_EC_mf0   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.018
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):              0.319
# Time:                        09:28:26   Log-Likelihood:                 784.71
# No. Observations:                  40   AIC:                            -1565.
# Df Residuals:                      38   BIC:                            -1562.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.183e-10   3.98e-10      1.301      0.201   -2.88e-10    1.32e-09
# ...

# %%
fooof_df.columns
# Out:
# Index([u'sub', u'age', u'sex', u'PO_EC_slope', u'PO_EC_yint', u'PO_EO_slope',
#        u'PO_EO_yint', u'MF_EC_slope', u'MF_EC_yint', u'MF_EO_slope',
#        u'MF_EO_yint', u'PO_EC_alphaPeak', u'PO_EC_alphaBW', u'PO_EC_alphaAMP',
#        u'PO_EO_alphaPeak', u'PO_EO_alphaBW', u'PO_EO_alphaAMP',
#        u'PO_EC_betaPeak', u'PO_EC_betaBW', u'PO_EC_betaAMP', u'PO_EO_betaPeak',
#        u'PO_EO_betaBW', u'PO_EO_betaAMP', u'PO_EC_thetaPeak', u'PO_EC_thetaBW',
#        u'PO_EC_thetaAMP', u'PO_EO_thetaPeak', u'PO_EO_thetaBW',
#        u'PO_EO_thetaAMP', u'MF_EC_alphaPeak', u'MF_EC_alphaBW',
#        u'MF_EC_alphaAMP', u'MF_EO_alphaPeak', u'MF_EO_alphaBW',
#        u'MF_EO_alphaAMP', u'MF_EC_betaPeak', u'MF_EC_betaBW', u'MF_EC_betaAMP',
#        u'MF_EO_betaPeak', u'MF_EO_betaBW', u'MF_EO_betaAMP',
#        u'MF_EC_thetaPeak', u'MF_EC_thetaBW', u'MF_EC_thetaAMP',
#        u'MF_EO_thetaPeak', u'MF_EO_thetaBW', u'MF_EO_thetaAMP',
# ...

# %%
import numpy as np

# %%
import scipy.stats
scipy.stats.pearsonr(fooof_df['PO_EC_slope'][~np.isnan(fooof_df['PO_EC_AMP_1'])], fooof_df['PO_EC_AMP_1'][~np.isnan(fooof_df['PO_EC_AMP_1'])])
# Out:
# (0.5723169859202777, 0.000405206091567427)

# %%
scipy.stats.pearsonr(psd_df['THETA_OVER_BETA_EC_po'][~np.isnan(fooof_df['PO_EC_AMP_1'])], fooof_df['PO_EC_AMP_1'][~np.isnan(fooof_df['PO_EC_AMP_1'])])
# Out:
# (0.6669375407470901, 1.652911802199659e-05)

# %%
ds = pd.read_csv('Data/MIPDB_digitSpan.csv')

# %%
ds['sub'] = ds['Anonymized ID']

# %%
df = pd.merge(ds, fooof_df, on='sub')

# %%
df.head()
# Out:
#    Unnamed: 0 Anonymized ID  Days since enrollment  \
# 0           2     A00051955                      0
# 1           6     A00053440                      0
# 2           9     A00053597                      0
# 3          10     A00053909                      0
# 4          12     A00054023                      0
#
#    Digit Span Backward Total Raw Score  Digit Span Forward Total Raw Score  \
# 0                                    7                                  11
# 1                                    6                                  10
# 2                                   13                                  11
# 3                                    6                                   9
# 4                                    8                                  10
#
#    Longest Digit Span Backward  Longest Digit Span Forward Subject Type  \
# 0                            4                           7      UNKNOWN
# ...

# %%
import statsmodels.formula.api as smf

# %%
df['DSBTRS']=df['Digit Span Backward Total Raw Score']
df['DSFTRS']=df['Digit Span Forward Total Raw Score']
df['LDSB']=df['Longest Digit Span Backward']
df['LDSF']=df['Longest Digit Span Forward']

# %%
smf.ols(formula = "LDSF ~ 1 + age + PO_EC_slope", data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   LDSF   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.230
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):              0.304
# Time:                        09:43:49   Log-Likelihood:                -64.227
# No. Observations:                  40   AIC:                             134.5
# Df Residuals:                      37   BIC:                             139.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.0855      1.298      3.147      0.003       1.455       6.716
# ...
